# %% [markdown]
# ## Environment
#
# 2020.07 colab Environment based.
#
# Ubuntu 18.04.3 LTS<br>
# Python version 3.6.9<br>
# pandas version 1.0.5<br>
# praat-parselmouth 0.3.3<br>

# %% [markdown]
# ### Install praat-parselmouth

# %%
# !pip install praat-parselmouth
# Out:
# Collecting praat-parselmouth
#   Downloading https://files.pythonhosted.org/packages/09/7b/9fa1172a63b6277603d27bb5613559b5a8888f58e68c1698017b87b0061d/praat_parselmouth-0.3.3-cp36-cp36m-manylinux1_x86_64.whl (9.0MB)
#      |████████████████████████████████| 9.0MB 2.7MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from praat-parselmouth) (1.18.5)
# Installing collected packages: praat-parselmouth
# Successfully installed praat-parselmouth-0.3.3

# %%
import glob
import parselmouth
import pandas as pd
import os

# %% [markdown]
# ### Get File directory (colab example)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 현재 디렉토리/sound 폴더 안에 .wav 파일이 존재함. 파일 총 개수 877개
len(glob.glob(os.getcwd()+'/sound/*.wav'))
# Out:
# 877

# %%
# 해당 디렉토리의 파일명을 리스트로 저장.
lists = glob.glob(os.getcwd()+'/sound/*.wav')
lists.sort(key = lambda x: (len(x), x))
lists[:10]
# Out:
# ['/content/drive/My Drive/성대계정/sound/0.wav',
#  '/content/drive/My Drive/성대계정/sound/1.wav',
#  '/content/drive/My Drive/성대계정/sound/2.wav',
#  '/content/drive/My Drive/성대계정/sound/3.wav',
#  '/content/drive/My Drive/성대계정/sound/4.wav',
#  '/content/drive/My Drive/성대계정/sound/5.wav',
#  '/content/drive/My Drive/성대계정/sound/6.wav',
#  '/content/drive/My Drive/성대계정/sound/7.wav',
#  '/content/drive/My Drive/성대계정/sound/8.wav',
#  '/content/drive/My Drive/성대계정/sound/9.wav']

# %%
# 결과를 저장할 디렉토리
path = os.getcwd()+'/sound/'

# %%
# 실패한 파일이름을 저장하는 리스트
failed_list = []

# pitch / formant 값을 저장할 데이터프레임
data = pd.DataFrame({
    "times":[],
    "F0(pitch)":[],
    "F1":[],
    "F2":[],
    'F3':[],
    "F4":[],
    "F5":[],
    "filename":[]
    })

# Formant 1 ~ 5까지 값을 구하기 위한 parameter
formants_value = ['F1','F2',"F3","F4","F5"]

# 각각의 음원파일을 for문으로 수행
for iters, soundpath in enumerate(lists, 1):
    try:
        # .wav 파일을 분석 가능한 Sound객체로 변환
        Sound = parselmouth.Sound(soundpath)

        # 0.1초 단위로 Formant를 계산한 객체
        formant = Sound.to_formant_burg(time_step = 0.1)
        
        # F0(pitch) 값 계산한 객체
        pitch = Sound.to_pitch()
        
        # Formant에서 사용한 0.1초 단위 timestamp를 dataframe으로 저장
        df = pd.DataFrame({"times":formant.ts()})
        
        # Formant Timestamp(0.1초 단위) 별 F1 ~ F5값 연산
        for idx, col in enumerate(formants_value, 1):
            df[col] = df['times'].map(lambda x: formant.get_value_at_time(formant_number = idx, time = x))
        
        # Formant Timestamp 별 Pitch값 계산
        df['F0(pitch)'] = df['times'].map(lambda x: pitch.get_value_at_time(time = x))
        
        # 파일명 저장
        df['filename'] = soundpath.split(path)[-1]
        
        # dataframe 업데이트
        data = data.append(df)
        
        # 진행상황 확인을 위한 로그
        if iters % 10 == 0:
            print("success: ", soundpath.split(path)[-1])
        
        # iteration 100 단위로 지금까지 실행한 음원데이터를 csv로 저장
        # colab의 런타임이 길지 않기 때문에, 지금까지 실행한 결과가 서버에서 지워질 수 있기 때문.
        if iters % 100 == 0:
            print(data)
            data.to_csv(str(iters) + ".csv")
        
    except Exception as e:
        # Exception 원인 출력
        print(e)
        # 실패한 파일 이름 저장
        failed_list.append(soundpath.split(path)[-1])
        # 어떤 파일에 문제가 있는지 확인
        print("fail: ", soundpath.split(path)[-1])

# 모든 작업이 끝나면, 최종 데이터를 finish.csv라는 이름으로 저장
data.to_csv('finish.csv')
# Out:
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/0.wav”.
# fail:  0.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/1.wav”.
# fail:  1.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/2.wav”.
# fail:  2.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/3.wav”.
# fail:  3.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/4.wav”.
# fail:  4.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/5.wav”.
# fail:  5.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/6.wav”.
# fail:  6.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/7.wav”.
# fail:  7.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/8.wav”.
# fail:  8.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/9.wav”.
# fail:  9.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/10.wav”.
# fail:  10.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/11.wav”.
# fail:  11.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/12.wav”.
# fail:  12.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/13.wav”.
# fail:  13.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/14.wav”.
# fail:  14.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/15.wav”.
# fail:  15.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/16.wav”.
# fail:  16.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/17.wav”.
# fail:  17.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/18.wav”.
# fail:  18.wav
# Not an audio file.
# Sound not read from sound file “/content/drive/My Drive/성대계정/sound/19.wav”.
# fail:  19.wav
# success:  30.wav
# success:  45.wav
# success:  56.wav
# success:  66.wav
# success:  76.wav
# success:  86.wav
# success:  142.wav
# success:  152.wav
#        times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.06         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.16  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.26  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.36  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.46  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...      ...         ...          ...  ...          ...          ...       ...
# 3138  313.85         NaN  1654.451322  ...          NaN          NaN   152.wav
# 3139  313.95         NaN  1532.634333  ...          NaN          NaN   152.wav
# 3140  314.05         NaN  1559.897089  ...  4045.391321          NaN   152.wav
# 3141  314.15         NaN  1499.241704  ...          NaN          NaN   152.wav
# 3142  314.25         NaN  1227.402926  ...  5447.927285          NaN   152.wav
#
# [196239 rows x 8 columns]
# success:  162.wav
# success:  172.wav
# success:  182.wav
# success:  193.wav
# success:  203.wav
# success:  213.wav
# success:  223.wav
# success:  850.wav
# success:  860.wav
# success:  870.wav
#        times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.06         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.16  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.26  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.36  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.46  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...      ...         ...          ...  ...          ...          ...       ...
# 1689  168.93         NaN  1434.117036  ...  3907.247380          NaN   870.wav
# 1690  169.03         NaN  1498.993361  ...          NaN          NaN   870.wav
# 1691  169.13         NaN  1499.019990  ...          NaN          NaN   870.wav
# 1692  169.23         NaN  1499.037592  ...          NaN          NaN   870.wav
# 1693  169.33         NaN  1499.047749  ...          NaN          NaN   870.wav
#
# [409855 rows x 8 columns]
# success:  881.wav
# success:  891.wav
# success:  901.wav
# success:  912.wav
# success:  922.wav
# success:  932.wav
# success:  942.wav
# success:  953.wav
# success:  964.wav
# success:  974.wav
#        times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.06         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.16  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.26  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.36  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.46  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...      ...         ...          ...  ...          ...          ...       ...
# 2284  228.46         NaN  1499.128512  ...          NaN          NaN   974.wav
# 2285  228.56         NaN  1499.116975  ...          NaN          NaN   974.wav
# 2286  228.66         NaN  1499.116084  ...          NaN          NaN   974.wav
# 2287  228.76         NaN  1499.113673  ...          NaN          NaN   974.wav
# 2288  228.86         NaN  1499.113495  ...          NaN          NaN   974.wav
#
# [631874 rows x 8 columns]
# success:  984.wav
# success:  995.wav
# success:  1005.wav
# success:  1015.wav
# success:  1026.wav
# success:  1036.wav
# success:  1046.wav
# success:  1056.wav
# success:  1066.wav
# success:  1076.wav
#         times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.060         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.160  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.260  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.360  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.460  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...       ...         ...          ...  ...          ...          ...       ...
# 2246  224.655         NaN  1429.779863  ...          NaN          NaN  1076.wav
# 2247  224.755         NaN  1476.223275  ...          NaN          NaN  1076.wav
# 2248  224.855         NaN  1498.189746  ...          NaN          NaN  1076.wav
# 2249  224.955         NaN  1499.103187  ...          NaN          NaN  1076.wav
# 2250  225.055         NaN  1499.103903  ...          NaN          NaN  1076.wav
#
# [848908 rows x 8 columns]
# success:  1087.wav
# success:  1097.wav
# success:  1191.wav
# success:  1202.wav
# success:  1212.wav
# success:  1222.wav
# success:  1232.wav
# success:  1243.wav
# success:  1253.wav
# success:  1263.wav
#        times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.06         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.16  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.26  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.36  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.46  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...      ...         ...          ...  ...          ...          ...       ...
# 1645  164.56         NaN  1456.933227  ...          NaN          NaN  1263.wav
# 1646  164.66         NaN  1499.156113  ...          NaN          NaN  1263.wav
# 1647  164.76         NaN  1499.157410  ...          NaN          NaN  1263.wav
# 1648  164.86         NaN  1499.155324  ...          NaN          NaN  1263.wav
# 1649  164.96         NaN  1499.156446  ...          NaN          NaN  1263.wav
#
# [1028543 rows x 8 columns]
# success:  1273.wav
# success:  1285.wav
# success:  1295.wav
# success:  1305.wav
# success:  1315.wav
# success:  1325.wav
# success:  1335.wav
# success:  1345.wav
# success:  1355.wav
# success:  1366.wav
#        times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.06         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.16  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.26  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.36  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.46  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...      ...         ...          ...  ...          ...          ...       ...
# 1568  156.87         NaN  1759.371967  ...          NaN          NaN  1366.wav
# 1569  156.97         NaN  1447.692851  ...          NaN          NaN  1366.wav
# 1570  157.07         NaN  1496.750039  ...          NaN          NaN  1366.wav
# 1571  157.17         NaN  1512.417926  ...          NaN          NaN  1366.wav
# 1572  157.27         NaN  1499.065670  ...          NaN          NaN  1366.wav
#
# [1202547 rows x 8 columns]
# success:  1376.wav
# success:  1395.wav
# success:  1405.wav
# success:  1415.wav
# success:  1425.wav
# success:  1436.wav
# success:  1448.wav
# success:  1458.wav
# success:  1469.wav
# success:  1480.wav
#       times   F0(pitch)           F1  ...           F4           F5  filename
# 0     0.060         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1     0.160  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2     0.260  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3     0.360  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4     0.460  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ..      ...         ...          ...  ...          ...          ...       ...
# 636  63.635         NaN  1499.080794  ...          NaN          NaN  1480.wav
# 637  63.735         NaN  1499.082159  ...          NaN          NaN  1480.wav
# 638  63.835         NaN  1499.083087  ...          NaN          NaN  1480.wav
# 639  63.935         NaN  1499.084299  ...          NaN          NaN  1480.wav
# 640  64.035         NaN  1499.085206  ...          NaN          NaN  1480.wav
#
# [1404574 rows x 8 columns]
# success:  1490.wav
# success:  1501.wav
# success:  1511.wav
# success:  1521.wav
# success:  1531.wav
# success:  1541.wav
# success:  1602.wav
# success:  1612.wav
# success:  1625.wav
# success:  1635.wav
#         times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.060         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.160  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.260  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.360  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.460  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...       ...         ...          ...  ...          ...          ...       ...
# 1820  182.035         NaN  1484.883080  ...          NaN          NaN  1635.wav
# 1821  182.135         NaN  1499.109177  ...          NaN          NaN  1635.wav
# 1822  182.235         NaN  1499.109132  ...          NaN          NaN  1635.wav
# 1823  182.335         NaN  1499.107933  ...          NaN          NaN  1635.wav
# 1824  182.435         NaN  1499.108865  ...          NaN          NaN  1635.wav
#
# [1585601 rows x 8 columns]
# success:  1745.wav
# success:  1755.wav
# success:  1765.wav
# success:  1775.wav
# success:  1785.wav
# success:  1795.wav
# success:  1805.wav

# %%
data
# pitch.get_value_at_time(time = 0.01)
# Out:
#         times   F0(pitch)           F1  ...           F4           F5  filename
# 0       0.060         NaN   668.956919  ...  3584.648268          NaN    21.wav
# 1       0.160  235.742471   481.937873  ...  3725.789058          NaN    21.wav
# 2       0.260  200.052051   509.083329  ...  3386.816847  3905.968303    21.wav
# 3       0.360  191.497127   721.980693  ...  3561.439324          NaN    21.wav
# 4       0.460  192.958886   413.574857  ...  3574.820304  4006.706467    21.wav
# ...       ...         ...          ...  ...          ...          ...       ...
# 1297  129.735         NaN   724.083957  ...  5449.009564          NaN    22.wav
# 1298  129.835         NaN  1499.099465  ...          NaN          NaN    22.wav
# 1299  129.935         NaN  1499.100308  ...          NaN          NaN    22.wav
# 1300  130.035         NaN  1499.100445  ...          NaN          NaN    22.wav
# 1301  130.135         NaN  1499.101241  ...          NaN          NaN    22.wav
#
# [4869 rows x 8 columns]

# %%
# 실패했던 파일을 json 형식 파일로 저장.
import json
with open('failed_file.json', 'w') as f:
    json.dump(failed_list, f, indent = 4)
